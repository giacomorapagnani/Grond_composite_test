# %% [markdown]
# # LIST Usefull commands + miscellaneous codes

# %% [markdown]
# # Grond screen simultaneous run
#
# ## execute file
# chmod +x run_grond_screen.sh
# ## run comands
# ./run_grond_screen.sh
#
# ## check screens
# screen -ls   # vedi quali screen sono ancora attivi (= analisi in corso)
# screen -r flegrei_2018_09_18_21_36_41   # entra in uno screen specifico
# ## Ctrl+A poi D per uscire senza fermarlo
#
# # avoid GIT conflicts:
# chmod +x run_grond_screen.sh
# git add run_grond_screen.sh
# git commit -m "Make script executable"
# git push
#
# ## usefull git comands
# git status
# git diff
# ## file restored to the local (mac) version
# git restore run_grond_screen.sh

# %% [markdown]
# # alias for 'python3 command'
# # (puts python3.11 version in the place of python3)
# echo 'alias python3="/opt/homebrew/bin/python3.11"' >> ~/.zshrc
#
# # Alternative:
# # Remove current python3 link if it exists
# brew unlink python@3.13
#
# # Create symlink to python3.11 (target version)
# ln -sf $(which python3.11) /opt/homebrew/bin/python3

# %% [markdown]
# ### MINICONDA comands

# %% [markdown]
# # activate miconda in current shell
# eval "$(/Users/giaco/miniconda3/bin/conda shell.zsh hook)"
#
# # close and re-open shell
# exec zsh -l
#
# # activate env
# conda activate grond_composite
#
# # deactivate env
# conda deactivate

# %% [markdown]
# ### Pyrocko and GROND CODE

# %% [markdown]
# # Stream in real time
#
# snuffler seedlink:"//geofon.gfz-potsdam.de/GE.*.*.BHZ" --follow=60
# snuffler seedlink:"//192.168.1.155/*" --follow=60

# %% [markdown]
# # install grond branch
# git clone <link>
#
# # Versions combinations:
#     # pyrocko & grond
#     # pyrocko-multi-triangle-stf & grond_composite
#     # pyrocko -> gf-combisource-stf ; grond -> composite
#
# # install pyrocko (inside pyrocko dir)
#     python3.11 install.py user
#
# # install grond (inside grond dir)
#     sudo pip install --no-deps .

# %% [markdown]
# # SSH unipi server EMA

# %% [markdown]
# ## connection
# ssh giacomo@131.114.9.179
# LinuxClient123
#
# # visual interface view:
# startx
#
# ## EVERYTIME: mount and unmount
# # mount Hard disk : DATA_EXT_2 (can be sda/sdb/sdc/sdd)
# sudo mount /dev/sdc /home/giacomo/jackhd
#
# # unmount Hard disk : DATA_EXT_2
# sudo umount /home/giacomo/jackhd

# %% [markdown]
# # SSH unipi server jishin

# %% [markdown]
# ## connection
# ssh sysop@131.114.9.207
# LinuxClient123
#
# ## venvs
# source ~/venvs/grond/bin/activate
# source ~/venvs/grond_composite_0/bin/activate
#
# # install
# git clone ...
# cd ...
# pip3 install .
#
# ### connect to remote pc
# ssh -Y giaco@131.114.9.179
#
# ### copy folder from local to remote (markers)
# scp -r /Users/giaco/UNI/PhD_CODE/GIT/Grond_composite_test/DATA sysop@131.114.9.207:/home/sysop/giaco/Grond_composite_test
# ### copy folder from remote to local (reports.tar)
# scp -r sysop@131.114.9.207:/home/sysop/giaco/Grond_composite_test/report/grond-report.tar.gz /Users/giaco/UNI/PhD_CODE/GIT/Grond_composite_test/

# %% [markdown]
# # VENV
#
# ## create
# python3.11 -m venv ~/venvs/NAME
# ## activate
# source ~/venvs/grond_composite_0/bin/activate
#
# ## deactivate
# deactivate
#
# # ____________________
# # install pyrocko (inside pyrocko dir, venv active)
# ## change git commit
# git fetch origin 7ca8c789c35b08653471d0285611efea32336348
# git checkout 7ca8c789c35b08653471d0285611efea32336348
# ## check git commit
# git rev-parse HEAD
# ## install
# python install.py deps pip
# python install.py user
#
# # ____________________
# # install grond (inside grond dir, venv active)
# ## change git commit
# git fetch origin 356e5b1f061c37de47da8fc998619f0f1d9d622b
# git checkout 356e5b1f061c37de47da8fc998619f0f1d9d622b
# ## check git commit
# git rev-parse HEAD
# ## install
# pip install --no-deps --no-build-isolation .
#
#
# ## clean cache
# hash -r
# ## fix path
# export PATH="$VIRTUAL_ENV/bin:$PATH"
# ## check installed packages
# pip freeze
# ## uninstal packages
# pip uninstall NAME

# %% [markdown]
# ### Grond GO all
# nohup grond go CONFIG/flegrei.devi... all --parallel=18 --force
#
# ### Grond REPORT all
# nohup grond report runs/cmt_devi_...* --parallel=18
#
# ### visualize reports
# grond report -so
#
# (???)
# grond plot -h
# (new default config file) (file type svg of pdf)
# grond plot new_config dir_event_figure
#
# ### create PDF figure in report
# grond plot plot.config.td <runs/cmt_>

# %% [markdown]
# # jacksies
# cut traces and devide them by stations
# jackseis <input folder> --output='%(station)s/%(network)s.%(station)s.%(channel)s.%(wmin)s.mseed' <outputfolder>

# %% [markdown]
# ### Terminal codes

# %% [markdown]
# ### terminal command
# ls -1 | wc -l   #number of element in directory
# ls -l       # date of file creation
# du -sh *    # size  of directory
# rm -rf      # remove recursively directory
# kill -9 'pid' # kill process
# cp -r # copy recursively
#
# scp...
# ssh...
#
# echo 'text' > <filename> #create filename with text inside
# chmod 777 <filename> # make file executable
# ./<filename> #run file

# %% [markdown]
# ### connect to remote pc
# ssh -Y giaco@131.114.9.179
#
# ### copy folder from local to remote (markers)
# scp -r  /Users/giaco/UNI/PhD_CODE/GIT/CAMPI_FLEGREI_moment_tensor/MARKERS giacomo@glic:/home/giacomo/GIT/CAMPI_FLEGREI_moment_tensor
#
# ### copy folder from remote to local (reports.tar)
# scp -r giacomo@glic:/home/giacomo/GIT/CAMPI_FLEGREI_moment_tensor/report/grond-report.tar.gz /Users/giaco/UNI/PhD_CODE/GIT/

# %% [markdown]
# ### Screen commands

# %% [markdown]
# ### GLIC commands
# ssh giacomo@glic
# pass: C204qwr!12a
#
# # create new screen
# screen -S <name>
#     # close screen but process runs in background
#     'control' 'A' + 'D'
#
# # check curent screens
# screen -r
#
# # enter existing screen and terminate
# screen -r <number>
#     exit
#
# # kill screen
# screen -X -S <n> quit
#
# srun -u --nodes=1  --ntasks=1 --mem=128G --cpus-per-task=N --time=2880 <COMMAND>
#
#     --pty
#
# grond report runs/cmt_devi_* --parallel=20

# %% [markdown]
# # DESKTOP PC GFZ
# user:giacomo
# password:giacomo
# ip:139.17.72.86
#
# ssh -Y giacomo@139.17.72.86
#
# scp -r  /Users/giaco/UNI/PhD_CODE/GIT/CAMPI_FLEGREI_moment_tensor/DATA giacomo@139.17.72.86:/home/giacomo/GIT/CAMPI_FLEGREI_moment_tensor
#
# scp -r giacomo@139.17.72.86:/home/giacomo/GIT/CAMPI_FLEGREI_moment_tensor/report/grond-report.tar.gz /Users/giaco/UNI/PhD_CODE/GIT/CAMPI_FLEGREI_moment_tensor/report
#
# # print
# scp -r  /Users/giaco/Desktop/print giacomo@139.17.72.86:/home/giacomo/Desktop/

# %% [markdown]
# ### -----------------------------------------------------------------------------
